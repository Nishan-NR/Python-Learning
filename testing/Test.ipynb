# %%
print("your age : ")
age=input()


print('You will be ' + str(int(age) + 1) + ' in a year.')
print(type(age))

# %%
x = input()
if x:
    print("hello")
print(x*2) #output will be 88 because by default input() treats every input as string
# Out:
# hello
# 22
