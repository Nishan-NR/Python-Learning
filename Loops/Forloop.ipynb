# %%
name = "oni"
global ver
ver = ("my name is " + name)
#ver = print("my name is " + name) -what is does is that it prints out the value without storing it 
for i in range(5):
    print(ver)

# %%
for i in range(5):
    print("jimmy five times ({})".format(i))
    print(f"jimmy five times ({i})") #using f-string
    print('jimmy five times ('+ str(i)+')') #using string concatenation

# %%
i = 1
while i <= 10:
    print(i)
    i += 1
